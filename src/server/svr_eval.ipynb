# %%
from sqlalchemy import text
import pandas as pd

from src.db.connector import get_db_connection
import plots.date_predictions as pdp

# %%
confusion_fig = pdp.plot_confusion_between_prediction_and_true_value(photos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 confusion_fig = pdp.plot_confusion_between_prediction_and_true_value(photos)
#
# File ~/MA4/flico/utils/plots/date_predictions.py:51, in plot_confusion_between_prediction_and_true_value(df, display)
#      49 owner_totals = pivot_df.groupby('owner_name')['count'].sum().sort_values(ascending=False)
#      50 owner_order = owner_totals.index.tolist()
# ---> 51 fig = px.scatter(
#      52     # df.sample(frac=0.03, random_state=42),
#      53     df,
#      54     x='true_date',
#      55     y='reg_n_pred_date',
#      56     color='owner_name',
#      57     labels={'true_date': 'actual_year', 'reg_n_pred_date': 'predicted_year'},
#      58     custom_data=['owner_name', 'url_n', 'page_url'],
#      59     category_orders={'owner_name': owner_order},
# ...

# %%
pdp.plot_institutions_per_year(photos)

# %%
pdp.plot_institutions_per_predicted_year(photos)

# %%
# pdp.plot_join_preds_actual_dates(photos)
